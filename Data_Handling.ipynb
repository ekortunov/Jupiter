# %%
import pandas as pd
import pyodbc as db
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.dates as mdates
import numpy as np

# %%
conn = db.connect('Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=D:\\Kortunov\\transfer\\Esentuk\\REGIM.mdb;')
curs = conn.cursor()
for row in curs.tables():
    print(row.table_name)
# Out:
# MSysAccessObjects
# MSysAccessXML
# MSysACEs
# MSysNavPaneGroupCategories
# MSysNavPaneGroups
# MSysNavPaneGroupToObjects
# MSysNavPaneObjectIDs
# MSysObjects
# MSysQueries
# MSysRelationships
# MainTable
# ВСЕ ДАННЫЕ

# %%
df = pd.read_sql_query("SELECT * FROM [ВСЕ ДАННЫЕ];", conn)
#pd.reset_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
curs.close()
conn.close()

# %%
df
# Out:
#         Year  Month  Day  Hour  Minute  IDPN       ДАТА  \
# 0       1972      1    3     0       0   127 1972-01-03
# 1       1972      1    4     0       0   127 1972-01-04
# 2       1972      1    5     0       0   127 1972-01-05
# 3       1972      1    6     0       0   127 1972-01-06
# 4       1972      1    7     0       0   127 1972-01-07
# ...      ...    ...  ...   ...     ...   ...        ...
# 424245  2020      2    8     0       0   348 2020-02-08
# 424246  2020      2    8     0       0   349 2020-02-08
# 424247  2020      2    8     0       0   355 2020-02-08
# 424248  2020      2    8     0       0  6001 2020-02-08
# 424249  2020      2    8     0       0  6002 2020-02-08
#
#         CO2_общая_(грамм_в_литре)  CO2_РАСТВОРЕННАЯ_(объемный_процент)  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                             NaN                                  NaN
# ...

# %%
welln = 111

s = df[df['IDPN'] == welln]
s
# Out:
#         Year  Month  Day  Hour  Minute  IDPN       ДАТА  \
# 29      1977      1    3     0       0   111 1977-01-03
# 45      1977      1    4     0       0   111 1977-01-04
# 54      1977      1    5     0       0   111 1977-01-05
# 63      1977      1    6     0       0   111 1977-01-06
# 72      1977      1    7     0       0   111 1977-01-07
# ...      ...    ...  ...   ...     ...   ...        ...
# 424010  2020      2    4     0       0   111 2020-02-04
# 424061  2020      2    5     0       0   111 2020-02-05
# 424111  2020      2    6     0       0   111 2020-02-06
# 424163  2020      2    7     0       0   111 2020-02-07
# 424212  2020      2    8     0       0   111 2020-02-08
#
#         CO2_общая_(грамм_в_литре)  CO2_РАСТВОРЕННАЯ_(объемный_процент)  \
# 29                            NaN                                  NaN
# 45                            NaN                                  NaN
# 54                            NaN                                  NaN
# ...

# %%
#def f(x):
#    return pd.Series([x.min(), x.max(),x.mean(),x.iloc[:,7:].median()], index=['min', 'max','mean','median'])

# %%
df.describe()
# Out:
#                 Year          Month            Day      Hour    Minute  \
# count  424250.000000  424250.000000  424250.000000  424250.0  424250.0
# mean     2002.273468       6.506859      15.751118       0.0       0.0
# std        12.167286       3.449236       8.776297       0.0       0.0
# min      1972.000000       1.000000       1.000000       0.0       0.0
# 25%      1992.000000       4.000000       8.000000       0.0       0.0
# 50%      2004.000000       7.000000      16.000000       0.0       0.0
# 75%      2013.000000      10.000000      23.000000       0.0       0.0
# max      2020.000000      12.000000      31.000000       0.0       0.0
#
#                IDPN  CO2_общая_(грамм_в_литре)  \
# count  4.242500e+05               24872.000000
# mean   7.367792e+03                   1.453075
# std    2.900570e+05                   0.711658
# min    9.700000e+01                   0.000000
# 25%    1.070000e+02                   0.716575
# ...

# %%
s.describe( include='all')
# Out:
#                 Year         Month           Day     Hour   Minute     IDPN  \
# count   15008.000000  15008.000000  15008.000000  15008.0  15008.0  15008.0
# unique           NaN           NaN           NaN      NaN      NaN      NaN
# top              NaN           NaN           NaN      NaN      NaN      NaN
# freq             NaN           NaN           NaN      NaN      NaN      NaN
# first            NaN           NaN           NaN      NaN      NaN      NaN
# last             NaN           NaN           NaN      NaN      NaN      NaN
# mean     1998.868603      6.505064     15.727545      0.0      0.0    111.0
# std        12.033418      3.450471      8.791094      0.0      0.0      0.0
# min      1977.000000      1.000000      1.000000      0.0      0.0    111.0
# 25%      1989.000000      4.000000      8.000000      0.0      0.0    111.0
# 50%      1999.000000      7.000000     16.000000      0.0      0.0    111.0
# ...

# %%
s
# Out:
#         Year  Month  Day  Hour  Minute  IDPN       ДАТА  \
# 29      1977      1    3     0       0   111 1977-01-03
# 45      1977      1    4     0       0   111 1977-01-04
# 54      1977      1    5     0       0   111 1977-01-05
# 63      1977      1    6     0       0   111 1977-01-06
# 72      1977      1    7     0       0   111 1977-01-07
# ...      ...    ...  ...   ...     ...   ...        ...
# 424010  2020      2    4     0       0   111 2020-02-04
# 424061  2020      2    5     0       0   111 2020-02-05
# 424111  2020      2    6     0       0   111 2020-02-06
# 424163  2020      2    7     0       0   111 2020-02-07
# 424212  2020      2    8     0       0   111 2020-02-08
#
#         CO2_общая_(грамм_в_литре)  CO2_РАСТВОРЕННАЯ_(объемный_процент)  \
# 29                            NaN                                  NaN
# 45                            NaN                                  NaN
# 54                            NaN                                  NaN
# ...

# %%
returns = s.iloc[:,8:].pct_change()
returns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-8280ba7c4655> in <module>
# ----> 1 returns = s.iloc[:,8:].pct_change()
#       2 returns
#
# NameError: name 's' is not defined

# %%
s['Свободная_СО2_(Проценты)'].corr(s['Напор_(SOLINST)_СРЕД_СУТ_(метры)'])
#s['Напор_(SOLINST)_СРЕД_СУТ_(метры)'].cov(s['Дебит_(м3_в_сут)'])

# %%
well111 = df[df['IDPN'] == 111]
well246 = df[df['IDPN'] == 246]
well111['Дебит_(м3_в_сут)'].corr(well246['Напор_(SOLINST)_СРЕД_СУТ_(метры)'], min_periods=100)

# %%
wellnumbers = pd.unique(df['IDPN'])
wellnumbers

# %%
df2 = df.set_index(['IDPN'], drop = False)
df2

# %%
well246

# %%
pivoted = df.pivot('ДАТА', 'IDPN')

# %%
pd.options.display.max_columns = 100

# %%
pivoted
# Out:
#                Year                                                        \
# IDPN       97       98       99       100      101      102      103
# ДАТА
# 1972-01-03      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1972-01-04      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1972-01-05      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1972-01-06      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1972-01-07      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...      ...
# 2020-02-04   2020.0      NaN   2020.0   2020.0   2020.0   2020.0      NaN
# 2020-02-05   2020.0      NaN   2020.0   2020.0   2020.0   2020.0      NaN
# 2020-02-06   2020.0      NaN   2020.0   2020.0   2020.0   2020.0      NaN
# 2020-02-07   2020.0      NaN   2020.0   2020.0   2020.0   2020.0      NaN
# 2020-02-08   2020.0      NaN   2020.0   2020.0   2020.0   2020.0      NaN
#
# ...

# %%
pivoted91 = pi
ivoted97
# Out:
# ДАТА
# 1972-01-03       NaN
# 1972-01-04       NaN
# 1972-01-05       NaN
# 1972-01-06       NaN
# 1972-01-07       NaN
#                ...
# 2020-02-04       NaN
# 2020-02-05       NaN
# 2020-02-06    0.9072
# 2020-02-07       NaN
# 2020-02-08       NaN
# Name: (CO2_общая_(грамм_в_литре), 140), Length: 15514, dtype: float64

# %%
plt.plot(pivoted.index, pivoted['Дебит_(м3_в_сут)', 99], color  = 'red',alpha = 0.8)

# %%
plt.plot(pivoted['Дебит_(м3_в_сут)', 102], pivoted['сухой_остаток_экспериментальный_(грамм_в_литре)', 112],'o', color  = 'red',alpha = 0.8, markersize = 10) 
#pivoted['Дебит', 140]
pivoted['магний-ион_Mg++_(грамм_в_литре)', 100]
#pivoted['Дебит', 140]
# Out:
# ДАТА
# 1972-01-03       NaN
# 1972-01-04       NaN
# 1972-01-05       NaN
# 1972-01-06       NaN
# 1972-01-07       NaN
#                ...
# 2020-02-04       NaN
# 2020-02-05    0.0754
# 2020-02-06       NaN
# 2020-02-07       NaN
# 2020-02-08       NaN
# Name: (магний-ион_Mg++_(грамм_в_литре), 100), Length: 15514, dtype: float64

# %%
plt.plot(pivoted.index, pivoted['хлорид_Cl-_(грамм_в_литре)', 143],'o', color  = 'red',alpha = 0.8, markersize = 10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-7eeca190de03> in <module>
# ----> 1 plt.plot(pivoted.index, pivoted['хлорид_Cl-_(грамм_в_литре)', 143, pivoted['Дебит_(м3_в_сут)', 99]],'o', color  = 'red',alpha = 0.8, markersize = 10)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2797         if is_single_key:
#    2798             if self.columns.nlevels > 1:
# -> 2799                 return self._getitem_multilevel(key)
#    2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_multilevel(self, key)
#    2847     def _getitem_multilevel(self, key):
#    2848         # self.columns is a MultiIndex
# -> 2849         loc = self.columns.get_loc(key)
# ...

# %%
#pivoted.index
#pivoted['Дебит_(м3_в_сут)', 251]
pivoted['Дебит_(м3_в_сут)', 111].corr(pivoted['Напор_(SOLINST)_СРЕД_СУТ_(метры)', 111], min_periods=100)
# Out:
# -0.9553790268701888

# %%
list(pivoted['Дебит_(м3_в_сут)'].columns)
#pivoted = pivoted.sort_index(axis=1)
Data = pivoted.drop(['Month','Year', 'Day','Hour','Minute'],axis = 1)

# %%
#pivoted.columns.get_level_values(1)
#Data['Дебит_(м3_в_сут)', 111].corr(Data.iloc['Напор_(SOLINST)_СРЕД_СУТ_(метры)', 111], min_periods=100)
df1 = df.drop(['Month','Year', 'Day','Hour','Minute','IDPN','ДАТА'],axis = 1)

# %%
b = 0
Data['Дебит_(м3_в_сут)',111]
wellnumbers =  pd.unique(df['IDPN'])#в переменную wellnumbers  записываем все уникальные номера скважин
columnames1 = list(df1.columns)# в переменную колумнейм1 записываем все имена колонок в таблице
for a in range(0,len(wellnumbers)):
    countnulls = Data['Дебит_(м3_в_сут)',wellnumbers[a]].count()#считаем сколько ненулевых значений в нашей текущей колонке (переменная неправильно названа)
    if countnulls > 0:# Если есть хоть одно значение(это можно и менять естсетсвенно) значит строим график
#        print(wellnumbers[a])
        for b in range(0,len(columnames1)):
            if str(columnames1[b]) != "Дебит_(м3_в_сут)":
                corr = Data['Дебит_(м3_в_сут)', wellnumbers[a]].corr(Data[columnames1[b], wellnumbers[a]], min_periods=100)
            if corr > 0.75 or corr <-0.75:
                print(str(wellnumbers[a])+ " " +str(columnames1[b])+ ' '+ str(corr))
# Out:
# 97 Динамический_уровень_от_точки_замера_(метры) -0.8137252165778258
# 97 Статический_уровень_от_точки_замера_(метры) -0.77873371023498
# 101 Напор_(ГИДЭК)_МИН_СУТ_(метры) -0.8842872646979033
# 101 Напор_(ГИДЭК)_СРЕД_СУТ_(метры) -0.9120608125291649
# 140 Динамический_уровень_от_точки_замера_(метры) 0.8064812476501398
# 140 Напор_(SOLINST)_МАКС_СУТ_(метры) 0.8596718063278054
# 140 Напор_(SOLINST)_СРЕД_СУТ_(метры) 0.9583237715139296
# 140 Статический_уровень_от_точки_замера_(метры) 0.8802258185014492
# 140 Температура_воды_(Градус_С) 0.8569176051793845
# 140 Температура_воды_замер_машиниста_(Градус_С) 0.8146865270157945
# 140 Температура_при_отборе_пробы_(Градус_С) 0.8183070668805287
# 141 Напор_(SOLINST)_СРЕД_СУТ_(метры) -0.8410575092010131
# 111 Газовый_фактор_(м3_в_м3) 0.7598135108466
# 111 гидрокарбонат_HCO3-_(грамм_в_литре) 0.7804689026095611
# 111 минерализация_(грамм_в_литре) 0.7939205181094042
# 111 Напор_(SOLINST)_МИН_СУТ_(метры) -0.823238065858457
# ...

# %%
b = 0
Data['Дебит_(м3_в_сут)',111]
wellnumbers =  pd.unique(df['IDPN'])#в переменную wellnumbers  записываем все уникальные номера скважин
columnames1 = list(df1.columns)# в переменную колумнейм1 записываем все имена колонок в таблице
for a in range(0,len(wellnumbers)):
    countnulls = Data['Дебит_(м3_в_сут)',wellnumbers[a]].count()#считаем сколько ненулевых значений в нашей текущей колонке (переменная неправильно названа)
    if countnulls > 0:# Если есть хоть одно значение(это можно и менять естсетсвенно) значит строим график
#        print(wellnumbers[a])
        for b in range(0,len(columnames1)):
            for z in range (0,len(wellnumbers)):
#                print(z)
                if str(columnames1[b]) != "Дебит_(м3_в_сут)":
                    corr = Data['Дебит_(м3_в_сут)', wellnumbers[a]].corr(Data[columnames1[b], wellnumbers[z]], min_periods=100)
                if corr > 0.75 or corr <-0.75:
                    print(str(wellnumbers[a])+" " + str(wellnumbers[z])+" " +str(columnames1[b])+ ' '+ str(corr))
# Out:
# 97 97 Динамический_уровень_от_точки_замера_(метры) -0.8137252165778258
# 97 101 Динамический_уровень_от_точки_замера_(метры) -0.7821877913184621
# 97 111 Динамический_уровень_от_точки_замера_(метры) -0.8662389692652972
# 97 121 Динамический_уровень_от_точки_замера_(метры) 0.9748855993984663
# 97 106 Динамический_уровень_от_точки_замера_(метры) -0.762875647424915
# 97 98 Динамический_уровень_от_точки_замера_(метры) -0.8370180049528276
# 97 250 Напор_(ГИДЭК)_МИН_СУТ_(метры) -0.7763457910743631
# 97 250 Опер__пьез__уровень,_КОНТРОЛЬ_ВЗУ_(метры) -0.769773721274436
# 97 97 Статический_уровень_от_точки_замера_(метры) -0.77873371023498
# 97 115 Статический_уровень_от_точки_замера_(метры) -0.834273384809746
# 97 109 Статический_уровень_от_точки_замера_(метры) -0.7982769180730492
# 97 110 Статический_уровень_от_точки_замера_(метры) -0.8627315684256759
# 100 104 Опер__пьез__уровень,_КОНТРОЛЬ_ВЗУ_(метры) -0.7792216684725655
# ...

# %%
# %gui

# %%
# %matplotlib inline

# %%
#%matplotlib notebook
plt.plot(np.arange(10))

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
# Out:
# C:\Users\Hydro\anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.
# C:\Users\Hydro\anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# ...

# %%
fig

# %%
plt.plot([1.5, 3.5, -2, 1.6]),
# Out:
# ([<matplotlib.lines.Line2D at 0x168983c3048>],)

# %%
from numpy.random import randn
plt.plot(randn(50).cumsum(), 'k--')

# %%
#_ = ax1.hist(randn(100), bins=20, color='k', alpha=0.3)
# %matplotlib inline
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))
#plt.show()

# %%
fig, axes = plt.subplots(2, 3, sharex = True, sharey = True, figsize=(30, 10))
fig

# %%
pd.plotting.scatter_matrix(Data['Температура_воды_(Градус_С)'], diagonal='kde', color='k', alpha=0.3)

# %%
grouped = df['CO2_общая_(грамм_в_литре)'].groupby(df['IDPN'])
grouped

# %%
grouped.mean()
# Out:
# IDPN
# 97          2.024841
# 98          1.267713
# 99          1.856306
# 100         1.896729
# 101         1.957881
#               ...
# 6002             NaN
# 10070            NaN
# 10071            NaN
# 11071            NaN
# 12098535         NaN
# Name: CO2_общая_(грамм_в_литре), Length: 86, dtype: float64

# %%
df.groupby(['Year','IDPN']).mean()
# Out:
#                    Month        Day  Hour  Minute  CO2_общая_(грамм_в_литре)  \
# Year IDPN
# 1972 127        1.000000  14.214286   0.0     0.0                        NaN
# 1977 97         6.526027  15.720548   0.0     0.0                        NaN
#      100        6.526027  15.720548   0.0     0.0                        NaN
#      101        6.528926  15.721763   0.0     0.0                        NaN
#      106       10.100000  16.350000   0.0     0.0                        NaN
# ...                  ...        ...   ...     ...                        ...
# 2020 6002       1.205128  13.641026   0.0     0.0                        NaN
#      10070      1.000000  14.000000   0.0     0.0                        NaN
#      10071      1.000000  13.880000   0.0     0.0                        NaN
#      11071      1.000000  14.500000   0.0     0.0                        NaN
#      12098535   1.000000  14.500000   0.0     0.0                        NaN
#
# ...

# %%
#df.groupby(['IDPN']).size()
df.groupby(['IDPN']).count()
# Out:
#            Year  Month    Day   Hour  Minute   ДАТА  \
# IDPN
# 97        14781  14781  14781  14781   14781  14781
# 98         3669   3669   3669   3669    3669   3669
# 99         7730   7730   7730   7730    7730   7730
# 100       14867  14867  14867  14867   14867  14867
# 101       14754  14754  14754  14754   14754  14754
# ...         ...    ...    ...    ...     ...    ...
# 6002       2429   2429   2429   2429    2429   2429
# 10070      3896   3896   3896   3896    3896   3896
# 10071      3920   3920   3920   3920    3920   3920
# 11071       145    145    145    145     145    145
# 12098535    244    244    244    244     244    244
#
#           CO2_общая_(грамм_в_литре)  CO2_РАСТВОРЕННАЯ_(объемный_процент)  \
# IDPN
# 97                             1553                                    1
# 98                               23                                    0
# 99                               18                                    0
# ...

# %%
pivoted.groupby(level= 1, axis=1).count()
# Out:
# IDPN        97        98        99        100       101       102       \
# ДАТА
# 1972-01-03         0         0         0         0         0         0
# 1972-01-04         0         0         0         0         0         0
# 1972-01-05         0         0         0         0         0         0
# 1972-01-06         0         0         0         0         0         0
# 1972-01-07         0         0         0         0         0         0
# ...              ...       ...       ...       ...       ...       ...
# 2020-02-04         9         0         8         9        14         8
# 2020-02-05        23         0         8        23        28         8
# 2020-02-06         9         0         8         9        14         8
# 2020-02-07         9         0         8         9        14         8
# 2020-02-08         9         0         8         9        14         8
#
# IDPN        103       104       105       106       107       108       \
# ДАТА
# ...

# %%
functions = ['count', 'mean', 'max']
grouped = df.groupby(['IDPN'])
result = grouped['CO2_РАСТВОРЕННАЯ_(объемный_процент)','CO2_РАСТВОРЕННАЯ_(см3_литре)'].agg(functions)
result
# Out:
# C:\Users\Hydro\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#          CO2_РАСТВОРЕННАЯ_(объемный_процент)                        \
#                                        count       mean        max
# IDPN
# 97                                         1  56.340000  56.340000
# 98                                         0        NaN        NaN
# 99                                         0        NaN        NaN
# 100                                        1  74.470001  74.470001
# 101                                        1  74.470001  74.470001
# ...                                      ...        ...        ...
# 6002                                       0        NaN        NaN
# 10070                                      0        NaN        NaN
# ...
