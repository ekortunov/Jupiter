# %%
#Импорт нужных библиотек. 
import pandas as pd
import pyodbc as db
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.dates as mdates
import numpy as np
import os
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
df = pd.read_excel('D:\\Kortunov\\test_nitrat_atr_1.xls')
df
# Out:
#                Zeitpunkt  BBR I Würmursprung, Altdorf  \
# 0    1985-12-05 10:00:00                          NaN
# 1    1986-04-17 14:30:00                          NaN
# 2    1986-10-23 10:30:00                          NaN
# 3    1987-04-09 11:45:00                          NaN
# 4    1987-11-11 13:45:00                          NaN
# ...                  ...                          ...
# 1690 2019-09-25 12:00:00                          NaN
# 1691 2019-12-04 08:50:00                          NaN
# 1692 2019-12-09 08:15:00                          NaN
# 1693 2019-12-09 10:00:00                          NaN
# 1694 2019-12-09 10:30:00                          NaN
#
#       BBR II Fa. Kraus Textilveredlung GmbH, Rottenburg am Neckar  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...

# %%
len(df.iloc[:,1:].columns)
df.iloc[:,29]

# %%
df.columns[3]
# Out:
# 'GWM 3 WPA-Waschanlage, Herrenberg-Affstätt'

# %%
fig = plt.figure()
ax = fig.add_subplot(6,1,1)# Тут примерно все тоже самое, только я создаю рисунок а на нем говорю, чтро будет 4 сабплота и в данном случае вызываю 1. 4 это количество, 1 это адрес по горищонтали, 1 это адрес по вертикали
#scatter graph
for a in range(1,28):
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)# Тут примерно все тоже самое, только я создаю рисунок а на нем говорю, чтро будет 4 сабплота и в данном случае вызываю 1. 4 это количество, 1 это адрес по горищонтали, 1 это адрес по вертикали
    lns1 = ax.plot(df.iloc[:,0], df.iloc[:,a],'o', alpha = 1, color = "maroon",label = 'Напор динамический',linewidth='0',markersize=7,zorder=0,markeredgewidth=0)
    ax.annotate('Локация: '+ str(df.columns[a]),
    xy=(0.5, 1.1), xycoords='axes fraction',
    horizontalalignment='center', verticalalignment='top',
    fontsize=9, color = 'black') #here goes the annotation of well number and well name in the top right of every subplot
# Out:
# C:\Users\Hydro\anaconda3\envs\New\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# C:\Users\Hydro\anaconda3\envs\New\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# ...
